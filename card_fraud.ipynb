# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitx84/Credit-Card-Fraud-Detection/blob/main/card_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Credit Card Fraud Detection - Using Logistic Regression**

# %% [markdown]
# importing required libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Reading the data

# %%
# loding data to pandas data frame
credit_card= pd.read_csv('creditcard.csv')

# %%
# to check data information
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# to check total no of rows and column in data
credit_card.shape
# Out:
# (284807, 31)

# %%
# just to determine null values in data
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of data as fraud and legit
credit_card['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# to describe the data
credit_card.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  1.168375e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
# classifying data as legit and fraud
legit= credit_card[credit_card.Class==0]
fraud= credit_card[credit_card.Class==1]

# %%
# to check all fraud values
fraud
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 541        406.0 -2.312227  1.951992  ... -0.143276    0.00      1
# 623        472.0 -3.043541 -3.157307  ...  0.035764  529.00      1
# 4920      4462.0 -2.303350  1.759247  ... -0.153029  239.93      1
# 6108      6986.0 -4.397974  1.358367  ...  0.849573   59.00      1
# 6329      7519.0  1.234235  3.019740  ...  0.146793    1.00      1
# ...          ...       ...       ...  ...       ...     ...    ...
# 279863  169142.0 -1.927883  1.125653  ...  0.147968  390.00      1
# 280143  169347.0  1.378559  1.289381  ...  0.186637    0.76      1
# 280149  169351.0 -0.676143  1.126366  ...  0.194361   77.89      1
# 281144  169966.0 -3.113832  0.585864  ... -0.253700  245.00      1
# 281674  170348.0  1.991976  0.158476  ... -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
# checking all legit value
legit
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284315 rows x 31 columns]

# %%
# as legit has more rows than fraud to equally distributing both
legit_new = legit.sample(n=len(fraud),random_state=2)

# %%
# checking new legit column
legit_new
# Out:
#             Time        V1        V2  ...       V28   Amount  Class
# 188671  128077.0 -3.288944 -4.809848  ... -0.548096  1206.14      0
# 190546  128878.0  2.020493 -1.000658  ... -0.063195    67.95      0
# 46318    42728.0  0.883694 -0.761362  ...  0.039590   150.00      0
# 267636  162855.0 -0.072377  0.735400  ...  0.263924    24.00      0
# 189610  128481.0 -0.264285  0.990040  ...  0.010990    14.28      0
# ...          ...       ...       ...  ...       ...      ...    ...
# 146264   87572.0 -3.264604  2.715905  ... -0.175061     4.00      0
# 265091  161736.0  1.860578  0.455548  ... -0.022831     5.55      0
# 182736  125528.0  1.879695 -0.669803  ... -0.027390    30.24      0
# 2371      1921.0 -0.899027 -0.216091  ...  0.046671   370.76      0
# 24400    33215.0  1.083359 -0.733445  ...  0.033011    79.00      0
#
# [492 rows x 31 columns]

# %%
# checking rows and column in new legit
legit_new.shape
# Out:
# (492, 31)

# %%
# merging both data legit_new and fraud to credit_card
credit_card = pd.concat([legit_new,fraud],axis=0)

# %%
# checking rows and column in credit_card
credit_card.shape
# Out:
# (984, 31)

# %%
# checking mean of legit_new and fraud to compare values of both
credit_card.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0      94317.294715 -0.093431 -0.154518  ... -0.021466  0.028256   86.271382
# 1      80746.806911 -4.771948  3.623778  ...  0.170575  0.075667  122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting the data in Feature and Target

# %%
X= credit_card.drop('Class',axis=1)
y= credit_card['Class']

# %%
X.shape
# Out:
# (984, 30)

# %% [markdown]
# Spliting data into Training data and Testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ### Model Training
# Logistic Regression

# %%
model= LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Model Evaluation
#
# Accuracy on Training and Testing Data

# %%
train_acc = accuracy_score(model.predict(X_train),y_train)
test_acc = accuracy_score(model.predict(X_test),y_test)
# Out:
# 0.9238578680203046
